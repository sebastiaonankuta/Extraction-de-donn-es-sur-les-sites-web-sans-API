# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#importer les bibliothèques
from bs4 import BeautifulSoup as bs
import requests
import json
import pandas as pd
#df= pd.read_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeDataTraité.xlsx")
#df

# %%
df=df["lien"]
list_url =df.values.tolist()

# %% [markdown]
# Numero de telefone

# %%
for i in range(len(list_url)-5560):
    try:
        #print(list_url[i])
        #url ="https://pros.lacentrale.fr/C049118?pro_only=0"
        req =requests.get(list_url[i]) #faire une requettte sr chacune de site web
        soup = bs(req.text,'html.parser')
        test = soup.find_all('a',{"class": 'bold'})
        print(test[1].text)
    except:
      print("erreur site : ", list_url[i])
# Out:
#                         04 86 80 73 15
#
#
#                         04 50 41 54 24
#
#
#                         04 74 22 89 89
#
#
#                         04 28 02 17 93
#
# erreur site :  https://pros.lacentrale.fr/C050024?pro_only=0
#
#                         04 28 39 02 93

# %% [markdown]
# Nom *societe*

# %%
url ="https://pros.lacentrale.fr/C049118?pro_only=0"
req =requests.get(url) #faire une requettte sr chacune de site web
soup = bs(req.text,'html.parser')
nomSociete = soup.find_all('span',{"class": 'txtDealer'})
nomSociete
# Out:
# [<span class="txtDealer"> DS STORE VALENCE
#
#        </span>]

# %% [markdown]
# Adresse

# %%
url ="https://pros.lacentrale.fr/C049118?pro_only=0"
req =requests.get(url) #faire une requettte sr chacune de site web
soup = bs(req.text,'html.parser')
#method2 = soup.find('div').find('span').text
Adresse = soup.find_all('span',{"class": 'w65 inlineBlock vMiddle'})
Adresse[3].text
#method2
# Out:
# ': 505 RTE DE CHABEUIL   VALENCE 26000'

# %%
l1=[],l2=[],l3=[],l4=[],l5_erreur=[]
for i in range(len(list_url)):
    try:
        print("site: ",i)
        #print(list_url[i])
        #url ="https://pros.lacentrale.fr/C049118?pro_only=0"
        req =requests.get(list_url[i]) #faire une requettte sr chacune de site web
        soup = bs(req.text,'html.parser')
        numero = soup.find_all('a',{"class": 'bold'})
        l1.append(numero[1].text)

        nomSociete = soup.find_all('span',{"class": 'txtDealer'})
        l2.append(nomSociete)

        Adresse = soup.find_all('span',{"class": 'w65 inlineBlock vMiddle'})
        l3.append(Adresse[3].text)
        l4.append(list_url[i])
        #print(numero[1].text)
    except:
      l5_erreur.append(list_url[i])
      print("erreur site : ",i," : ",list_url[i])
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# site:  756
# site:  757
# site:  758
# site:  759
# site:  760
# site:  761
# site:  762
# site:  763
# site:  764
# site:  765
# site:  766
# site:  767
# site:  768
# site:  769
# site:  770
# site:  771
# site:  772
# site:  773
# site:  774
# site:  775
# site:  776
# site:  777
# site:  778
# site:  779
# site:  780
# site:  781
# site:  782
# site:  783
# site:  784
# site:  785
# site:  786
# site:  787
# site:  788
# site:  789
# site:  790
# site:  791
# site:  792
# site:  793
# site:  794
# site:  795
# site:  796
# site:  797
# site:  798
# site:  799
# site:  800
# site:  801
# site:  802
# site:  803
# site:  804
# site:  805
# site:  806
# site:  807
# site:  808
# site:  809
# site:  810
# site:  811
# site:  812
# site:  813
# site:  814
# site:  815
# site:  816
# site:  817
# erreur site :  817  :  https://pros.lacentrale.fr/C035711?pro_only=0
# site:  818
# site:  819
# site:  820
# ...

# %%
l5_erreur
# Out:
# ['https://pros.lacentrale.fr/C050024?pro_only=0',
#  'https://pros.lacentrale.fr/C049550?pro_only=0',
#  'https://pros.lacentrale.fr/C049872?pro_only=0',
#  'https://pros.lacentrale.fr/C049530?pro_only=0',
#  'https://pros.lacentrale.fr/C049341?pro_only=0',
#  'https://pros.lacentrale.fr/C049537?pro_only=0',
#  'https://pros.lacentrale.fr/C049800?pro_only=0',
#  'https://pros.lacentrale.fr/C048083?pro_only=0',
#  'https://pros.lacentrale.fr/C048910?pro_only=0',
#  'https://pros.lacentrale.fr/C049793?pro_only=0',
#  'https://pros.lacentrale.fr/C048034?pro_only=0',
#  'https://pros.lacentrale.fr/C049822?pro_only=0',
#  'https://pros.lacentrale.fr/C049497?pro_only=0',
#  'https://pros.lacentrale.fr/C049087?pro_only=0',
#  'https://pros.lacentrale.fr/C049464?pro_only=0',
#  'https://pros.lacentrale.fr/C049226?pro_only=0',
#  'https://pros.lacentrale.fr/C049371?pro_only=0',
#  'https://pros.lacentrale.fr/C049337?pro_only=0',
#  'https://pros.lacentrale.fr/C048660?pro_only=0',
# ...

# %%
df7= pd.DataFrame(l5_erreur)

# %%
df7.to_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/ErreurData.xlsx")

# %%
len(l5_erreur)
# Out:
# 219

# %%
df1= pd.DataFrame(l1)
df2= pd.DataFrame(l2)
df3= pd.DataFrame(l3)
df4= pd.DataFrame(l4)
df = pd.concat([df1,df2,df3,df4], axis=1)

# %%
df
# Out:
#                                                       0  ...                                              0
# 0     \n                        04 86 80 73 15 \n   ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1     \n                        04 50 41 54 24 \n   ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2     \n                        04 74 22 89 89 \n   ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3     \n                        04 28 02 17 93 \n   ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4     \n                        04 28 39 02 93 \n   ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343  \n                        01 76 28 34 28 \n   ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344  \n                        06 64 72 22 38 \n   ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %%
df.to_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeOK.xlsx")

# %%
df= pd.read_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeOK.xlsx")
df = df.replace(r'\n',' ', regex=True) 
df
# Out:
#                                        numero telephone  ...                                       Site web
# 0                              04 86 80 73 15       ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1                              04 50 41 54 24       ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2                              04 74 22 89 89       ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3                              04 28 02 17 93       ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4                              04 28 39 02 93       ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343                           01 76 28 34 28       ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344                           06 64 72 22 38       ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %% [markdown]
# supprimer saute de lignes

# %%
df = df.replace(r'\n',' ', regex=True) 
df
# Out:
#                                        numero telephone  ...                                       Site web
# 0                              04 86 80 73 15       ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1                              04 50 41 54 24       ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2                              04 74 22 89 89       ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3                              04 28 02 17 93       ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4                              04 28 39 02 93       ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343                           01 76 28 34 28       ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344                           06 64 72 22 38       ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %% [markdown]
# supprimer les characters speciaux

# %%
df["Nom commercial"]=  df["Nom commercial"].replace(r'[^0-9a-zA-Z ]', '', regex=True).replace("'", '')
df
# Out:
#                                        numero telephone  ...                                       Site web
# 0                              04 86 80 73 15       ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1                              04 50 41 54 24       ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2                              04 74 22 89 89       ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3                              04 28 02 17 93       ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4                              04 28 39 02 93       ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343                           01 76 28 34 28       ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344                           06 64 72 22 38       ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %% [markdown]
# supprimer les 21 premieres strings et 4 dernieres

# %%
df["Nom commercial"] = df["Nom commercial"].str[20:]
df
# Out:
#                                        numero telephone  ...                                       Site web
# 0                              04 86 80 73 15       ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1                              04 50 41 54 24       ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2                              04 74 22 89 89       ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3                              04 28 02 17 93       ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4                              04 28 39 02 93       ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343                           01 76 28 34 28       ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344                           06 64 72 22 38       ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %%
df["Nom commercial"] = df["Nom commercial"].str[:-4]
df
# Out:
#                                        numero telephone  ...                                       Site web
# 0                              04 86 80 73 15       ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1                              04 50 41 54 24       ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2                              04 74 22 89 89       ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3                              04 28 02 17 93       ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4                              04 28 39 02 93       ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343                           01 76 28 34 28       ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344                           06 64 72 22 38       ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %%
df5 = df['Adrersse'].str[-5:]
df5
# Out:
# 0       01250
# 1       01170
# 2       01000
# 3       01100
# 4       01480
#         ...
# 5343    30377
# 5344    95700
# 5345    95150
# 5346    95460
# 5347      NaN
# Name: Adrersse, Length: 5348, dtype: object

# %%
df = pd.concat([df, df5],axis=1)

# %%
df
# Out:
#                                        numero telephone  ... Adrersse
# 0                              04 86 80 73 15       ...  ...    01250
# 1                              04 50 41 54 24       ...  ...    01170
# 2                              04 74 22 89 89       ...  ...    01000
# 3                              04 28 02 17 93       ...  ...    01100
# 4                              04 28 39 02 93       ...  ...    01480
# ...                                                 ...  ...      ...
# 5343                           01 76 28 34 28       ...  ...    30377
# 5344                           06 64 72 22 38       ...  ...    95700
# 5345                           01 76 47 16 49       ...  ...    95150
# 5346                           01 39 95 45 00       ...  ...    95460
# 5347                           06 25 67 47 17       ...  ...      NaN
#
# [5348 rows x 5 columns]

# %%
df.to_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeOK1.xlsx")
df= pd.read_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeOK1.xlsx")
df
# Out:
#       Unnamed: 0  ...  Adrersse.1
# 0            NaN  ...      1250.0
# 1            NaN  ...      1170.0
# 2            NaN  ...      1000.0
# 3            NaN  ...      1100.0
# 4            NaN  ...      1480.0
# ...          ...  ...         ...
# 5343         NaN  ...     30377.0
# 5344         NaN  ...     95700.0
# 5345         NaN  ...     95150.0
# 5346         NaN  ...     95460.0
# 5347         NaN  ...         NaN
#
# [5348 rows x 7 columns]

# %%
df["Adrersse"] = df["Adrersse"].str[1:]
df
# Out:
#       Unnamed: 0  ...  Adrersse.1
# 0            NaN  ...      1250.0
# 1            NaN  ...      1170.0
# 2            NaN  ...      1000.0
# 3            NaN  ...      1100.0
# 4            NaN  ...      1480.0
# ...          ...  ...         ...
# 5343         NaN  ...     30377.0
# 5344         NaN  ...     95700.0
# 5345         NaN  ...     95150.0
# 5346         NaN  ...     95460.0
# 5347         NaN  ...         NaN
#
# [5348 rows x 7 columns]

# %%
df.to_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeOK1.xlsx")
df= pd.read_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/MergeOK1.xlsx")
df
# Out:
#       Unnamed: 0  ...  Adrersse.1
# 0              0  ...      1250.0
# 1              1  ...      1170.0
# 2              2  ...      1000.0
# 3              3  ...      1100.0
# 4              4  ...      1480.0
# ...          ...  ...         ...
# 5343        5343  ...     30377.0
# 5344        5344  ...     95700.0
# 5345        5345  ...     95150.0
# 5346        5346  ...     95460.0
# 5347        5347  ...         NaN
#
# [5348 rows x 8 columns]

# %%
df["Nom commercial"] = df["Nom commercial"].str[:3]

# %%
df
# Out:
#                                        numero telephone  ...                                       Site web
# 0                              04 86 80 73 15       ...  ...  https://pros.lacentrale.fr/C044860?pro_only=0
# 1                              04 50 41 54 24       ...  ...  https://pros.lacentrale.fr/C043921?pro_only=0
# 2                              04 74 22 89 89       ...  ...  https://pros.lacentrale.fr/C048450?pro_only=0
# 3                              04 28 02 17 93       ...  ...  https://pros.lacentrale.fr/C030480?pro_only=0
# 4                              04 28 39 02 93       ...  ...  https://pros.lacentrale.fr/C047075?pro_only=0
# ...                                                 ...  ...                                            ...
# 5343                           01 76 28 34 28       ...  ...  https://pros.lacentrale.fr/C018221?pro_only=0
# 5344                           06 64 72 22 38       ...  ...  https://pros.lacentrale.fr/C044918?pro_only=0
# ...

# %%
df["Nom commercial"] = df["Nom commercial"].str[:-3]
df

# %%
df1["numero"]= pd.DataFrame(l1)
#df2["nom societé"]= pd.DataFrame(l2)
df3["adresse"]= pd.DataFrame(l3)
df4["adresse"]= pd.DataFrame(l4)
df = pd.concat([df1,df3,df3], axis=1)

# %%
df.to_excel("/content/drive/MyDrive/NOTAIRES SCRAPPING/lacentrale/Merge.xlsx")

# %%
df

# %%
l3
# Out:
# [': 2921 ROUTE NATIONALE 75   MONTAGNAT 01250',
#  ': 686 AVENUE FRANCIS BLANCHARD   GEX 01170',
#  ': 28 AVENUE MARECHAL JUIN   BOURG EN BRESSE 01000',
#  ': 46 ROUTE DE DORTAN   OYONNAX 01100',
#  ': 7 CHEMIN DU CHENE   CHALEINS 01480']

# %%
url ="https://pros.lacentrale.fr/C049118?pro_only=0"
req =requests.get(url) #faire une requettte sr chacune de site web
soup = bs(req.text,'html.parser')
#method2 = soup.find('div').find('span').text
nomSociete = soup.find_all('span',{"class": 'w65 inlineBlock vMiddle'})
nomSociete
#method2
# Out:
# [<span class="w65 inlineBlock vMiddle">: FINANCIERE TG</span>,
#  <span class="w65 inlineBlock vMiddle">: MINODIER AUTOMOBILES</span>,
#  <span class="w65 inlineBlock vMiddle">: 680000</span>,
#  <span class="w65 inlineBlock vMiddle">: 505 RTE DE CHABEUIL   VALENCE 26000</span>,
#  <span class="w65 inlineBlock vMiddle">: 435881339</span>,
#  <span class="w65 inlineBlock vMiddle">: FR27435881339</span>]

# %%
url ="https://pros.lacentrale.fr/C049118?pro_only=0"
req =requests.get(url) #faire une requettte sr chacune de site web
soup = bs(req.text,'html.parser')
ville = soup.find_all('div',{"class": 'floatL onlyPrint'})
ville

# %%
l1= soup.findAll("script")
l1
# Out:
# [<script crossorigin="" src="https://www.lacentrale.fr/static/fragment-mozart/2.3.6-require.js"></script>,
# ...

# %%
l1[19]
# Out:
# <script>
# ...

# %%
l1[19].text
# Out:
# '\n  var VitrinesAnnuaireData = {"queryString":{"limitrophe":"false","zipcode":"86"},"makes":["ABARTH","AIXAM","ALFA ROMEO","ALPINE","ASTON MARTIN","AUDI","BENTLEY","BMW","CHATENET","CHEVROLET","CHRYSLER","CITROEN","CUPRA","DACIA","DAEWOO","DS","FERRARI","FIAT","FORD","HONDA","HYUNDAI","ISUZU","IVECO","JAGUAR","JEEP","KIA","LADA","LAMBORGHINI","LAND ROVER","LEXUS","LIGIER","LOTUS","MASERATI","MAZDA","MCLAREN","MERCEDES","MG","MINI","MITSUBISHI","MULTIMARQUE","NISSAN","OPEL","PEUGEOT","PGO","PORSCHE","RENAULT","SAAB","SEAT","SKODA","SMART","SSANGYONG","SUBARU","SUZUKI","TOYOTA","VOLKSWAGEN","VOLVO"],"rubrique":"AUTO","vitrines":[{"item":{"id":"C026128","vehicleFamily":"AUTO","publishedName":"ALIZON AUTOMOBILES","address":{"street1":"ZA DES CHAUMETTES","zipCode":"86270","department":"86","city":"LA ROCHE POSAY","country":"FRANCE","location":{"latitude":46.7944768,"longitude":0.7970444999999999}},"make":"CITROEN","active":true,"phone1":"0532140352","hasSlideShow":true,"cuRef":"C026128",
# ...

# %% [markdown]
# Dataframe Nom Notaire

# %%
import pandas as pd
l1 =[]
for elt in Notary__Result__Name:
    l1.append(elt.text)
l1
# Out:
# ['\nCéline GALY-CARCENAC\n',
#  '\nJean-Christophe CHAPUT\n',
#  '\nDidier SENANEDJ\n',
#  '\nJosèpha BOYER\n',
#  '\nBoris BLANC\n',
#  '\nPascal POTIER\n',
#  '\nHervé SFEZ\n',
#  '\nPierre VIGNALOU\n',
#  '\nDelphine LUCIEN-COIRRE\n',
#  '\nAlexis SANCHEZ\n',
#  '\nChristine CHEVALIER\n',
#  '\nMurielle GAMET\n',
#  '\nMaria-Hélène KREMER\n',
#  '\nVéronique DEJEAN de la BATIE\n',
#  '\nEmily MANGEOT\n',
#  '\nRichard RENAULT\n',
#  '\nSophie JARDIN\n',
#  '\nJeanne PIFFAUT\n',
#  '\nOlivier JOURDE\n',
#  '\nStéphanie SIROT\n',
#  '\nYann MOREAU-COTTEN\n',
#  '\nJuliette HACKER\n',
#  '\nJean DUPONT-CARIOT\n',
#  '\nAdrien DE SAINT JACOB\n',
#  '\nSabine BARDET-LIEY\n',
#  '\nMarie CLUZEAU-CHESNOY\n',
#  '\nSophie CASCALES\n',
#  '\nEmily BELLESSA\n',
#  '\nAmélie DOUSSOT\n',
#  '\nSandrine ILLER\n',
#  '\nJérôme TERRIER\n',
#  '\nAnthony SAVALE\n',
#  '\nJean-Marie BERGERET\n',
#  '\nMatthieu DUFOSSÉ\n',
#  '\nTiphaine CAZAL-BEXON\n',
#  '\nAgathe MARBAUD de BRENIGNAN\n',
# ...

# %%
df1= pd.DataFrame(l1)
df1
# Out:
#                                0
# 0       \nCéline GALY-CARCENAC\n
# 1     \nJean-Christophe CHAPUT\n
# 2            \nDidier SENANEDJ\n
# 3              \nJosèpha BOYER\n
# 4                \nBoris BLANC\n
# ...                          ...
# 2051        \nEmmanuel JUBAULT\n
# 2052         \nIsabelle CHOURI\n
# 2053          \nMagalie CARBON\n
# 2054          \nCyrille LELONG\n
# 2055       \nLaurence HERVOUET\n
#
# [2056 rows x 1 columns]

# %% [markdown]
# separation du nom et prenom

# %%
#separation du nom et prenom

# %%
#df1.columns =['Nom et prenom']  
df1= pd.DataFrame(l1)
df1.columns = ['Nom et prenom']
#separer nom et prenom
new = df1["Nom et prenom"].str.split(" ", n = 1, expand = True)
# making separate first name column from new data frame
df1["Prenom"]= new[0]
# making separate last name column from new data frame
df1["Nom"]= new[1]
df1.drop(df1.columns[[0]], axis = 1, inplace = True)
df1
# Out:
#                  Prenom              Nom
# 0              \nCéline  GALY-CARCENAC\n
# 1     \nJean-Christophe         CHAPUT\n
# 2              \nDidier       SENANEDJ\n
# 3             \nJosèpha          BOYER\n
# 4               \nBoris          BLANC\n
# ...                 ...              ...
# 2051         \nEmmanuel        JUBAULT\n
# 2052         \nIsabelle         CHOURI\n
# 2053          \nMagalie         CARBON\n
# 2054          \nCyrille         LELONG\n
# 2055         \nLaurence       HERVOUET\n
#
# [2056 rows x 2 columns]

# %% [markdown]
# Site web office notaire

# %%
l2=[]
for elt in Notary__Result__Name:
     try:
        l2.append("https://www.notaires.fr"+elt.a.attrs['href'])
     except:
            print("An exception occurred:  ",Notary__Result__Name)

# %%
l2
# Out:
# ['https://www.notaires.fr/fr/notaire/helene-baudru-schappler-paris-75',
#  'https://www.notaires.fr/fr/notaire/guillaume-lembo-paris-75',
#  'https://www.notaires.fr/fr/notaire/jean-wintzer-wehekind-paris-75',
#  'https://www.notaires.fr/fr/notaire/gautier-richard-paris-75',
#  'https://www.notaires.fr/fr/notaire/olivier-lecomte-paris-75',
#  'https://www.notaires.fr/fr/notaire/muriel-mignard-paris-75',
#  'https://www.notaires.fr/fr/notaire/brigitte-marchay-paris-75',
#  'https://www.notaires.fr/fr/notaire/mathilde-lecomte-paris-75',
#  'https://www.notaires.fr/fr/notaire/sophie-valeriani-paris-75',
#  'https://www.notaires.fr/fr/notaire/lucile-chevillard-paris-75',
#  'https://www.notaires.fr/fr/notaire/nicolas-malard-paris-75',
#  'https://www.notaires.fr/fr/notaire/corinne-hermann-paris-75',
#  'https://www.notaires.fr/fr/notaire/charlotte-sophie-leconte-paris-75',
#  'https://www.notaires.fr/fr/notaire/marc-cagniart-paris-75',
# ...

# %%
df2= pd.DataFrame(l2)
df2.columns =['site web'] 
df2
# Out:
#                                                site web
# 0     https://www.notaires.fr/fr/notaire/celine-galy...
# 1     https://www.notaires.fr/fr/notaire/jean-christ...
# 2     https://www.notaires.fr/fr/notaire/didier-sena...
# 3     https://www.notaires.fr/fr/notaire/josepha-boy...
# 4     https://www.notaires.fr/fr/notaire/boris-blanc...
# ...                                                 ...
# 2051  https://www.notaires.fr/fr/notaire/emmanuel-ju...
# 2052  https://www.notaires.fr/fr/notaire/isabelle-ch...
# 2053  https://www.notaires.fr/fr/notaire/magalie-car...
# 2054  https://www.notaires.fr/fr/notaire/cyrille-lel...
# 2055  https://www.notaires.fr/fr/notaire/laurence-he...
#
# [2056 rows x 1 columns]

# %% [markdown]
# Adresse notaire office

# %%
#Addresse
l3 =[]
Notary__Result__Location__Address  = soup.find_all('span', class_ = 'Notary__Result__Location__Address')
for elt in Notary__Result__Location__Address:
    l3.append(elt.text)
l3
# Out:
# ['55, Boulevard Haussmann',
#  '9 RUE D ASTORG',
#  '4 AVENUE HOCHE',
#  '13 RUE AUBER',
#  '140 BOULEVARD HAUSSMANN',
#  '134 BOULEVARD HAUSSMANN',
#  '13 RUE SAINT ANTOINE',
#  '70 BOULEVARD DE PORT ROYAL',
#  '5 rue Alfred de Vigny',
#  '13 rue de Caumartin',
#  '3 RUE DE TURBIGO',
#  '55, Boulevard Haussmann',
#  '5 rue Alfred de Vigny',
#  '7-11 QUAI ANDRE CITROEN',
#  '140 BOULEVARD HAUSSMANN',
#  '128 BOULEVARD DE COURCELLES',
#  '3 RUE MONTALIVET',
#  '137 139 RUE MARCADET',
#  '10 RUE ST ANTOINE',
#  '38 AVENUE HOCHE',
#  '79 RUE JOUFFROY D ABBANS',
#  '9 rue Alfred de Vigny',
#  '5 AVENUE DE MESSINE',
#  '78 rue de Turbigo ',
#  '137 rue de l’Université',
#  '3 PLACE DES VICTOIRES',
#  '142 BOULEVARD HAUSSMANN',
#  '9 RUE D ASTORG',
#  '7 rue Joseph Bara',
#  "6 RUE SAINT LOUIS EN L'ÎLE",
#  '128 BOULEVARD DE COURCELLES',
#  '85 BOULEVARD HAUSSMANN',
#  '134 BOULEVARD HAUSSMANN',
#  '5 rue Alfred de Vigny',
#  '6, Rue de Miromesnil',
#  '64 AVENUE KLEBER',
# ...

# %% [markdown]
# Ville

# %%
l4=[]
Notary__Result__Location__City  = soup.find_all('span', class_ = 'Notary__Result__Location__City')
for elt in Notary__Result__Location__City:
        l4.append(elt)
l4
# Out:
# [<span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75009 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75004 PARIS</span>,
#  <span class="Notary__Result__Location__City">75005 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75009 PARIS</span>,
#  <span class="Notary__Result__Location__City">75001 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75008 PARIS</span>,
#  <span class="Notary__Result__Location__City">75015 PARIS</span>,
# ...

# %%
l4=[]
Notary__Result__Location__City  = soup.find_all('span', class_ = 'Notary__Result__Location__City')
for elt in Notary__Result__Location__City:
        l4.append(elt.text)
l4
# Out:
# ['75017\xa0PARIS',
#  '75011\xa0PARIS',
#  '75017\xa0PARIS',
#  '75017\xa0PARIS',
#  '75017\xa0PARIS',
#  '75008\xa0PARIS',
#  '75017\xa0PARIS',
#  '75008\xa0PARIS',
#  '75001\xa0PARIS',
#  '75013\xa0PARIS',
#  '75001\xa0PARIS',
#  '75010\xa0PARIS',
#  '75013\xa0PARIS',
#  '75017\xa0PARIS',
#  '75008\xa0PARIS',
#  '75008\xa0PARIS',
#  '75017\xa0PARIS',
#  '75017\xa0PARIS',
#  '75017\xa0PARIS',
#  '75007\xa0PARIS',
#  '75017\xa0PARIS',
#  '75009\xa0PARIS',
#  '75009\xa0PARIS',
#  '75006\xa0PARIS',
#  '75015\xa0PARIS',
#  '75008\xa0PARIS',
#  '75002\xa0PARIS',
#  '75008\xa0PARIS',
#  '75005\xa0PARIS',
#  '75008\xa0PARIS',
#  '75007\xa0PARIS',
#  '75001\xa0PARIS',
#  '75001\xa0PARIS',
#  '75005\xa0PARIS',
#  '75008\xa0PARIS',
#  '75001\xa0PARIS',
#  '75017\xa0PARIS',
#  '75008\xa0PARIS',
#  '75002\xa0PARIS',
#  '75008\xa0PARIS',
#  '75007\xa0PARIS',
#  '75017\xa0PARIS',
#  '75008\xa0PARIS',
#  '75011\xa0PARIS',
#  '75017\xa0PARIS',
#  '75008\xa0PARIS',
#  '75008\xa0PARIS',
# ...

# %%
df4= pd.DataFrame(l4)
df4.columns = ['Ville']

# %%
df4= pd.DataFrame(l4)
df4.columns = ['Ville']
#extraire code postal
df4["Code Postal"] = df4['Ville'].str.extract(r'(\d+)').astype(str) 
#remove int in the ville
df4["Ville"] = df4['Ville'].str.replace('\d+', '') 
df4
# Out:
#                        Ville Code Postal
# 0                      PARIS       75008
# 1                      PARIS       75008
# 2                      PARIS       75008
# 3                      PARIS       75009
# 4                      PARIS       75008
# ...                      ...         ...
# 2051       NEUILLY SUR SEINE       92200
# 2052               VINCENNES       94300
# 2053   SAINT-MAUR-DES-FOSSÉS       94100
# 2054                COLOMBES       92700
# 2055                 CLAMART       92140
#
# [2056 rows x 2 columns]

# %% [markdown]
# Adresse mail

# %%
l5= []
list_url = df2["site web"].values.tolist()
url =list_url # url égale à la liste des adresse  web

#parcourir la liste
for i in range(len(list_url)-2040):
    req1 =requests.get(list_url[i]) #faire une requettte sr chacune de site web
    soup1 = bs(req1.text,'html.parser')
    Notary__Section__Link = soup1.find_all('span',{"class": 'Notary__Section__Link'})[2].find_all(href=True)
    l5.append(Notary__Section__Link)

l5= pd.DataFrame(l5) #site

# %%
l5
# Out:
#                                 0
# 0   [Envoyer un email à l’office]
# 1   [Envoyer un email à l’office]
# 2   [Envoyer un email à l’office]
# 3   [Envoyer un email à l’office]
# 4   [Envoyer un email à l’office]
# 5                            None
# 6   [Envoyer un email à l’office]
# 7   [Envoyer un email à l’office]
# 8   [Envoyer un email à l’office]
# 9   [Envoyer un email à l’office]
# 10  [Envoyer un email à l’office]
# 11  [Envoyer un email à l’office]
# 12  [Envoyer un email à l’office]
# 13  [Envoyer un email à l’office]
# 14  [Envoyer un email à l’office]

# %%
df5.columns =['Adresse email']

# %%
df4["Code Postal"] = df4['Ville'].str.extract(r'(\d+)').astype(str) #extraire code postal

# %%
Notary__Result__Location__Address  = soup.find_all('span', class_ = 'Notary__Result__Location__Address')

# %%
Notary__Result__Location__Address
# Out:
# [<span class="Notary__Result__Location__Address">79 RUE JOUFFROY D ABBANS</span>,
#  <span class="Notary__Result__Location__Address">6 rue des Immeubles Industriels</span>,
#  <span class="Notary__Result__Location__Address">72 AVENUE DE WAGRAM</span>,
#  <span class="Notary__Result__Location__Address">128 BOULEVARD DE COURCELLES</span>,
#  <span class="Notary__Result__Location__Address">29, Avenue Mac Mahon</span>,
#  <span class="Notary__Result__Location__Address">15 avenue Matignon</span>,
#  <span class="Notary__Result__Location__Address">72 AVENUE DE WAGRAM</span>,
#  <span class="Notary__Result__Location__Address">142 BOULEVARD HAUSSMANN</span>,
#  <span class="Notary__Result__Location__Address">4 RUE PERRAULT</span>,
#  <span class="Notary__Result__Location__Address">49 AVENUE DES GOBELINS</span>,
#  <span class="Notary__Result__Location__Address">26 Avenue de l'Opéra</span>,
#  <span class="Notary__Result__Location__Address">16 PLACE DE LA REPUBLIQUE</span>,
# ...

# %%
Notary__Result__Office = soup.find_all('div',{"class": 'Notary__Result__Office'})
Notary__Result__Office
# Out:
# [<div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        Althémis Paris, SELARL    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        PIGNOL, notaire associé, SELARL    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        SAS C&amp;C notaires    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        SAS MICHELEZ NOTAIRES    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        SAS 14 PYRAMIDES NOTAIRES    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        SAS MATIGNON NOTAIRES    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        SAS C&amp;C notaires    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
# ...

# %%
Notary__Result__Name = soup.find_all('h2',{"class": 'Notary__Result__Name'})
Notary__Result__Office = soup.find_all('i',{"class": 'Notary__Result__Office'})
Notary__Result__Location = soup.find_all('span',{"class": 'Notary__Result__Location'})
Notary__Result__Location__Address = soup.find_all('span',{"class": 'Notary__Result__Location__Address'})
Notary__Result__Location__City = soup.find_all('span',{"class": 'Notary__Result__Location__City'})

# %%
Notary__Result__Office
# Out:
# []

# %%
Notary__Result__Office = soup.find_all('div',{"class": 'Notary__Result__Office'})
Notary__Result__Office
# Out:
# [<div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        DEJAUNE et associée    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        ROCHELOIS-BESINS &amp; ASSOCIES, SELAS    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        VOLLE Emmanuel    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        CARRÉ notaires, SELAS    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        BOIDIN Hélène    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        GIRARDOT et associés    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
#        SAS MOREL d'ARLEUX Notaires    </div>, <div class="Notary__Result__Office">
#  <i class="icon-notaire icon-office"></i>
# ...

# %%
#Nom notaire
l4=[]
for elt in Notary__Result__Office:
    nom_notaire = bs(str(elt)).get_text()
    l4.append(nom_notaire)
l4
# Out:
# ['\n\n      FLORENTIN et associés, SELARL    ',
#  '\n\n      SARL VH 15 NOTAIRES    ',
#  '\n\n      GERARD et associés    ',
#  '\n\n      BUSSIERE, notaire associé    ',
#  '\n\n      LASAYGUES & ASSOCIES SELARL    ',
#  '\n\n      DURANT des AULNOIS et associés    ',
#  '\n\n      BEAUCHET, NOTAIRE ASSOCIE, SELARL    ',
#  '\n\n      PIGNOL, notaire associé, SELARL    ',
#  '\n\n      DOUVIER, notaire associé, SELAS    ',
#  '\n\n      ROCHELOIS-BESINS & ASSOCIES, SELAS    ',
#  '\n\n      ALLEZ & ASSOCIES    ',
#  '\n\n      LACOURTE et associés, SELAS    ',
#  '\n\n      MARCEAU et associés, SELARL    ',
#  '\n\n      SAS Monceau Notaires    ',
#  '\n\n      SAS KL    ',
#  '\n\n      DELESALLE et associés    ',
#  '\n\n      WARGNY KATZ    ',
#  '\n\n      WARGNY KATZ    ',
#  '\n\n      LATIL Benjamin    ',
#  '\n\n      BOURDEL et associés    ',
#  '\n\n      MAURIOS Laurence    ',
#  '\n\n      AGUESSEAU NOTAIRES, SELAS    ',
#  '\n\n      MARIE et associés    ',
# ...

# %% [markdown]
# get adresse mail

# %%
#------------------------------get adresse mail----------------------------------------------
#convert a site web column i the a list of url
list_url = df2["site web"].values.tolist()

# %%
len(list_url)
# Out:
# 2056

# %%
l5= []
list_url = df2["site web"].values.tolist()
url =list_url
for i in range(len(list_url)):
    req1 =requests.get(list_url[i])
    soup1 = bs(req1.text,'html.parser')
    Notary__Section__Link = soup1.find_all('span',{"class": 'Notary__Section__Link'})[2].find_all(href=True)
    l5.append(Notary__Section__Link)
l5
# Out:
# [[<a href="mailto:communication@cheuvreux.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:thibierge.associes@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [],
#  [<a href="mailto:sjjr@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:haussmann-notaires@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [],
#  [<a href="mailto:etude.sfez@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:acontrario@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:allezetassocies@allezetassocies.com">Envoyer un email à l’office</a>],
#  [<a href="mailto:alexis.sanchez@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:scp.gilles@paris.notaires.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:communication@cheuvreux.fr">Envoyer un email à l’office</a>],
#  [<a href="mailto:allezetassocies@allezetassocies.com">Envoyer un email à l’office</a>],
# ...

# %%
#Trouver le nom de notaire
from bs4 import BeautifulSoup
#html_soup = BeautifulSoup(response.text, 'html.parser')
#Notary__Result__Name = html_soup.find_all('h2', class_ = 'Notary__Result__Name')
Notary__Result__Name = soup.find_all('h2',{"class": 'Notary__Result__Name'})
Notary__Result__Office = soup.find_all('i',{"class": 'Notary__Result__Office'})
Notary__Result__Location = soup.find_all('span',{"class": 'Notary__Result__Location'})
Notary__Result__Location__Address = soup.find_all('span',{"class": 'Notary__Result__Location__Address'})
Notary__Result__Location__City = soup.find_all('span',{"class": 'Notary__Result__Location__City'})



print(len(Notary__Result__Name))


l1 =[]
#print("Notary__Result__Name: ",Notary__Result__Name)
for elt in Notary__Result__Name:
    #print("Notary__Result__Name: ",elt.a.text)
    l1.append(elt.a)
# Out:
# 1978

# %%
import pandas as pd
df1= pd.DataFrame(l1)

# %%
df1
# Out:
#                          0
# 0          Laurent PARGADE
# 1              Julie BRAMI
# 2            Valérie RENOU
# 3     Mélanie GOMES DAMIAO
# 4        François CAYROCHE
# ...                    ...
# 1973     Christine BAUGUIL
# 1974     Laurence HERVOUET
# 1975        Marine LECHUGA
# 1976         Hélène LAPEZE
# 1977         David SERRERO
#
# [1978 rows x 1 columns]

# %%
Notary__Result__Office = soup.find('div',{"class": 'Notary__Result__Office'})

Notary__Result__Location = soup.find('h2',class_= 'Notary__Result__Location')
Notary__Result__Location__Address = soup.find('span',class_= 'Notary__Result__Location__Address')
Notary__Result__Location__City = soup.find('h2',class_= 'Notary__Result__Location__City')

print("offce: ---->", Notary__Result__Office)
print("Adress: ", Notary__Result__Location__Address)
print("City: ", Notary__Result__Location__City)

# %%
print(Notary__Result__Name)
# Out:
# None

# %%
# Out:
# []

# %%
Notary__Result__Name = soup.find('div',attrs={'class','class="Notary__Result-inner'})



books = Notary__Result__Name.find_all('Notary__Result-inner')

# %%
import requests
with open ('simple.html') as html_file:
     soup =bs(html_file, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-7129c414d688> in <module>()
#       1 import requests
# ----> 2 with open ('simple.html') as html_file:
#       3      soup =bs(html_file, 'lxml')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'simple.html'

# %%
Notary__Result__Name = soup.find('i',class_= 'Notary__Result__Name')
print(Notary__Result__Name)
headline = Notary__Result__Name.a.text
print(headline)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa50063ebb96> in <module>()
#       1
# ----> 2 Notary__Result__Name = soup.find('i',class_= 'Notary__Result__Name')
#       3 print(Notary__Result__Name)
#       4 headline = Notary__Result__Name.a.text
#       5 print(headline)
#
# NameError: name 'soup' is not defined

# %%
summary =Notary__Result__Name.find('h2',class_='entry-content')

# %%
summary

# %% [markdown]
# Autre façon de lire

# %%
source = requests.get('https://www.notaires.fr/fr/annuaires-notaire/recherche/localisation/Creteil/').text
soup =bs(source, 'lxml')
Notary__Result__Name = soup.find('Notary__Result__Name')

# %%
Notary__Result__Name

# %%
headline = Notary__Result__Name.a.text
print(headline)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-c14f33324765> in <module>()
# ----> 1 headline = Notary__Result__Name.a.text
#       2 print(headline)
#
# AttributeError: 'NoneType' object has no attribute 'a'

# %%
for Notary__Result__Name in soup.find('div',class_= 'Notary__Result__Name'):
    headline =Notary__Result__Name.h2.a.text
    print(heagline)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html class="no-js ie lt-ie9 lt-ie8 lt-ie7 lte-ie10" lang="fr"> <![endif]-->
# <!--[if IE 7]> <html class="no-js ie ie7 lt-ie9 lt-ie8 lte-ie10" lang="fr"> <![endif]-->
# <!--[if IE 8]> <html class="no-js ie ie8 lt-ie9 lte-ie10" lang="fr"> <![endif]-->
# <!--[if IE 9]> <html class="no-js ie ie9 lt-ie10 lte-ie10" lang="fr"> <![endif]-->
# <!--[if lte IE 10]> <html class="no-js ie lte-ie10" lang="fr"> <![endif]-->
# <!--[if !IE]><!--> <html class="no-js" lang="fr"> <!--<![endif]-->
# <head>
# <meta content="0BTd6yasKLb5lr4iHzcrSHufayI3GyPkAh-JEcjZ0ls" name="google-site-verification"/>
# <meta charset="utf-8"/>
# <!--[if IE]>
#             <meta name="application-name" content="www.notaires.fr | Notaires de France" />
#             <meta name="msapplication-tooltip" content="www.notaires.fr | Notaires de France" />
#             <meta name="msapplication-window" content="width=1024;height=768" />
# ...

# %% [markdown]
# soup
